# %%
import pandas as pd

# %%
movie = pd.read_csv("Resources/tmdb_5000_movies.csv")
movie.head()
crew = pd.read_csv("Resources/tmdb_5000_credits.csv")
crew.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
director = crew.crew.str.split("Directing", expand = True).filter([1])
newfilters = director.rename(columns = {1: 'director'})
newfilters = newfilters.director.str.split(':',expand = True).filter([4]).rename(columns = {4:'director'})
movie = newfilters.director.str.split('}',expand = True).filter([0]).rename(columns = {0:'director'}).merge(movie, right_index = True, left_index = True)
movie.head()
# Out:
#                director     budget  \
# 0       "James Cameron"  237000000
# 1      "Gore Verbinski"  300000000
# 2          "Sam Mendes"  245000000
# 3   "Christopher Nolan"  250000000
# 4      "Andrew Stanton"  260000000
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# ...

# %%
filters = movie.production_companies.str.split(',',expand = True).filter([0])
newfilters = filters.rename(columns = {0: 'Company'})
newfilters = newfilters.Company.str.split(':',expand = True).filter([1])
movie = newfilters.rename(columns = {1:"production_company"}).merge(movie, right_index = True, left_index = True)
movie
# Out:
#                            production_company               director  \
# 0                   "Ingenious Film Partners"        "James Cameron"
# 1                      "Walt Disney Pictures"       "Gore Verbinski"
# 2                         "Columbia Pictures"           "Sam Mendes"
# 3                        "Legendary Pictures"    "Christopher Nolan"
# 4                      "Walt Disney Pictures"       "Andrew Stanton"
# 5                         "Columbia Pictures"            "Sam Raimi"
# 6                      "Walt Disney Pictures"         "Byron Howard"
# 7                            "Marvel Studios"          "Joss Whedon"
# 8                              "Warner Bros."          "David Yates"
# 9                                 "DC Comics"          "Zack Snyder"
# 10                                "DC Comics"         "Bryan Singer"
# 11                          "Eon Productions"         "Marc Forster"
# 12                     "Walt Disney Pictures"       "Gore Verbinski"
# ...

# %%
genre = movie.genres.str.split(',',expand = True).filter([1])
newgenre= genre.rename(columns = {1: 'genre'})
newgenre = newgenre.genre.str.split(':',expand = True).filter([1])
newgenre= newgenre.rename(columns = {1: 'genre'})
newgenre = newgenre.genre.str.split('}',expand = True).filter([0])
movie= newgenre.rename(columns = {0: 'genre'}).merge(movie, right_index = True, left_index = True)
movie
# Out:
#                    genre                       production_company  \
# 0               "Action"                "Ingenious Film Partners"
# 1            "Adventure"                   "Walt Disney Pictures"
# 2               "Action"                      "Columbia Pictures"
# 3               "Action"                     "Legendary Pictures"
# 4               "Action"                   "Walt Disney Pictures"
# 5              "Fantasy"                      "Columbia Pictures"
# 6            "Animation"                   "Walt Disney Pictures"
# 7               "Action"                         "Marvel Studios"
# 8            "Adventure"                           "Warner Bros."
# 9               "Action"                              "DC Comics"
# 10           "Adventure"                              "DC Comics"
# 11           "Adventure"                        "Eon Productions"
# 12           "Adventure"                   "Walt Disney Pictures"
# ...

# %%
movie = movie.drop('genres',1)
movie = movie.drop('production_companies',1)
movie = movie.drop('homepage',1)
movie = movie.drop('keywords',1)
movie = movie.drop('original_language',1)
movie = movie.drop('spoken_languages',1)
movie = movie.drop('production_countries',1)
movie = movie.drop('original_title',1)

# %%
movie=movie.rename(columns = {'id':'identification'})
movie.head()
# Out:
#           genre          production_company              director     budget  \
# 0      "Action"   "Ingenious Film Partners"       "James Cameron"  237000000
# 1   "Adventure"      "Walt Disney Pictures"      "Gore Verbinski"  300000000
# 2      "Action"         "Columbia Pictures"          "Sam Mendes"  245000000
# 3      "Action"        "Legendary Pictures"   "Christopher Nolan"  250000000
# 4      "Action"      "Walt Disney Pictures"      "Andrew Stanton"  260000000
#
#    identification                                           overview  \
# 0           19995  In the 22nd century, a paraplegic Marine is di...
# 1             285  Captain Barbossa, long believed to be dead, ha...
# 2          206647  A cryptic message from Bond’s past sends him o...
# 3           49026  Following the death of District Attorney Harve...
# 4           49529  John Carter is a war-weary, former military ca...
#
#    popularity release_date     revenue  runtime    status  \
# ...

# %%
# Out:
#           genre          production_company              director     budget  \
# 0      "Action"   "Ingenious Film Partners"       "James Cameron"  237000000
# 1   "Adventure"      "Walt Disney Pictures"      "Gore Verbinski"  300000000
# 2      "Action"         "Columbia Pictures"          "Sam Mendes"  245000000
# 3      "Action"        "Legendary Pictures"   "Christopher Nolan"  250000000
# 4      "Action"      "Walt Disney Pictures"      "Andrew Stanton"  260000000
#
#    identification                                           overview  \
# 0           19995  In the 22nd century, a paraplegic Marine is di...
# 1             285  Captain Barbossa, long believed to be dead, ha...
# 2          206647  A cryptic message from Bond’s past sends him o...
# 3           49026  Following the death of District Attorney Harve...
# 4           49529  John Carter is a war-weary, former military ca...
#
#    popularity release_date     revenue  runtime    status  \
# ...

# %%
movie.to_csv('Resources/cleanedmovies.csv')
